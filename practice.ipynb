# %%
print("let's startttt")
# Out:
# let's startttt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Everything works!")
# Out:
# Everything works!

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["A", "B", "C"],
    "Age": [20, 21, 22]
})

df
# Out:
#   Name  Age
# 0    A   20
# 1    B   21
# 2    C   22

# %%
# to activate the venv
# venv\Scripts\activate

# %%
# to deactive the venv
# deactivate

# %%
# http://127.0.0.1:8000
# http://127.0.0.1:8000/docs
